# %%
import pandas as pd
df1 = pd.read_csv('passengerData.csv')

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
df2 = pd.read_excel('ticketPrices.xlsx')
df2
# Out:
#    TicketType  Fare
# 0           1    33
# 1           2    56
# 2           3    77
# 3           4    22
# 4           5    14
# 5           6    66
# 6           7    87
# 7           8    36

# %%
new = pd.merge(df1, df2, on='TicketType')

# %%
new
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              9         1       3
# 2             17         0       3
# 3             25         0       3
# 4             33         1       3
# ..           ...       ...     ...
# 886          856         1       3
# 887          864         0       3
# 888          872         1       1
# 889          880         1       1
# 890          888         1       1
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 2                                 Rice, Master. Eugene    male   2.0
# 3                        Palsson, Miss. Torborg Danira  female   8.0
# 4                             Glynn, Miss. Mary Agatha  female   NaN
# ..                                                 ...     ...   ...
# ...

# %%
new['Name'].loc[new['Age'] == new['Age'].max()]
# Out:
# 747    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
x  = new['Name'][new['Age'] == new['Age'].max()]
x.values
# Out:
# array(['Barkworth, Mr. Algernon Henry Wilson'], dtype=object)

# %%
print("The Names are : ")
for i in x:
    print(i)
# Out:
# The Names are :
# Barkworth, Mr. Algernon Henry Wilson

# %%
import matplotlib.pyplot as plt

ax = plt.axes
plt.scatter(new['Fare'], new.Age)
plt.xlabel("Fare")
plt.ylabel("Age")
plt.show()

# %%
female_new  = new.loc[(new.Age > 40) & (new.Age < 50) & (new.Sex == 'female') & (new.Fare >= 40)]
female_new
# Out:
#      PassengerId  Survived  Pclass  \
# 154          338         1       1
# 220          866         1       2
# 248          195         1       1
# 269          363         0       3
# 312          707         1       2
# 318          755         1       2
# 700          255         0       3
# 748          639         0       3
# 753          679         0       3
# 775          855         0       2
# 776          863         1       1
#
#                                                   Name     Sex   Age  \
# 154                    Burns, Miss. Elizabeth Margaret  female  41.0
# 220                           Bystrom, Mrs. (Karolina)  female  42.0
# 248          Brown, Mrs. James Joseph (Margaret Tobin)  female  44.0
# 269                    Barbara, Mrs. (Catherine David)  female  45.0
# 312                      Kelly, Mrs. Florence "Fannie"  female  45.0
# 318                   Herman, Mrs. Samuel (Jane Laver)  female  48.0
# ...

# %%
ax = plt.axes
plt.scatter(female_new['Fare'], female_new.Age)
plt.xlabel("Fare")
plt.ylabel("Age")
plt.show()
